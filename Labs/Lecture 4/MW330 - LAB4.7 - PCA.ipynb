# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = sns.load_dataset('diamonds')
df = df.iloc[:5000,:]
df['price_bin'] = pd.cut(df.price, 4)

# %% [markdown]
# # EDA

# %%
sns.pairplot(data=df[['x','y','z']]);plt.show()

# %%
sns.pairplot(data=df[['x', 'y', 'z', 'price_bin']], hue='price_bin');plt.show()
# Out:
# C:\Users\peer.kueppers\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA
X = df[['x', 'y', 'z']]  # these are the features we want to use
pca = PCA(n_components=2)
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
X_new = pd.DataFrame(pca.transform(X))
X_new['price_bin'] = df['price_bin']  # attach the original price bins (X_new has the same length as df!)
sns.pairplot(data=X_new, hue='price_bin');plt.show()
# Out:
# C:\Users\peer.kueppers\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
